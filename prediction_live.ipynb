# %%
import yfinance as yf
import os
import pandas as pd
import matplotlib
import datetime

# %%
#puts all BTC data into a ticker
btc_ticker = yf.Ticker("BTC-USD")

# %%
#creates csv file with btc data from yahoo finance
if os.path.exists("BTC-USD"):
    btc = pd.read_csv("btc.csv", index_col=0)
else:
    btc = btc_ticker.history(period="max")
    btc.to_csv("btc.csv")

# %%
btc
# Out:
#                                    Open          High           Low
# Date
# 2014-09-17 00:00:00+00:00    465.864014    468.174011    452.421997  \
# 2014-09-18 00:00:00+00:00    456.859985    456.859985    413.104004
# 2014-09-19 00:00:00+00:00    424.102997    427.834991    384.532013
# 2014-09-20 00:00:00+00:00    394.673004    423.295990    389.882996
# 2014-09-21 00:00:00+00:00    408.084991    412.425995    393.181000
# ...                                 ...           ...           ...
# 2023-05-25 00:00:00+00:00  26329.460938  26591.519531  25890.593750
# 2023-05-26 00:00:00+00:00  26474.181641  26916.669922  26343.949219
# 2023-05-27 00:00:00+00:00  26720.181641  26888.882812  26621.140625
# 2023-05-28 00:00:00+00:00  26871.158203  28193.449219  26802.751953
# 2023-05-29 00:00:00+00:00  28163.041016  28418.039062  27579.240234
#
#                                   Close       Volume  Dividends  Stock Splits
# Date
# 2014-09-17 00:00:00+00:00    457.334015     21056800        0.0           0.0
# 2014-09-18 00:00:00+00:00    424.440002     34483200        0.0           0.0
# 2014-09-19 00:00:00+00:00    394.795990     37919700        0.0           0.0
# 2014-09-20 00:00:00+00:00    408.903992     36863600        0.0           0.0
# 2014-09-21 00:00:00+00:00    398.821014     26580100        0.0           0.0
# ...                                 ...          ...        ...           ...
# 2023-05-25 00:00:00+00:00  26476.207031  13851122697        0.0           0.0
# 2023-05-26 00:00:00+00:00  26719.291016  12711619225        0.0           0.0
# 2023-05-27 00:00:00+00:00  26868.353516   7892015141        0.0           0.0
# 2023-05-28 00:00:00+00:00  28085.646484  14545229578        0.0           0.0
# 2023-05-29 00:00:00+00:00  27649.179688  17052137472        0.0           0.0
#
# [3177 rows x 7 columns]

# %%
#converts all info to datetime to make it more manageable
btc.index = pd.to_datetime(btc.index)

# %%
#delete unwanted colums
del btc["Dividends"]
del btc["Stock Splits"]

# %%
#convert everything to lowerwcase to make it easier to deal with
btc.columns = [c.lower() for c in btc.columns]

# %%
#create graph of btc to current day
btc.plot.line(y="close", use_index=True)
# Out:
# <Axes: xlabel='Date'>

# %%
#read wiki sentiment analysis file
wiki = pd.read_csv("wikipedia_edits.csv", index_col=0, parse_dates=True)

# %%
wiki
# Out:
#             edit_count  sentiment  neg_sentiment
# 2009-04-06    0.133333  -0.018351          0.025
# 2009-04-07    0.000000   0.000000          0.000
# 2009-04-08    0.000000   0.000000          0.000
# 2009-04-09    0.000000   0.000000          0.000
# 2009-04-10    0.000000   0.000000          0.000
# ...                ...        ...            ...
# 2023-05-20    0.000000   0.000000          0.000
# 2023-05-21    0.000000   0.000000          0.000
# 2023-05-22    0.000000   0.000000          0.000
# 2023-05-23    0.000000   0.000000          0.000
# 2023-05-24    0.000000   0.000000          0.000
#
# [5162 rows x 3 columns]

# %%
#set btc datetime timezone to none to match wiki timezone
btc = btc.tz_localize(None)

# %%
#merge btc csv with the sentiment analysis file
btc = btc.merge(wiki, left_index=True, right_index=True)

# %%
btc
# Out:
#                     open          high           low         close
# 2014-09-17    465.864014    468.174011    452.421997    457.334015  \
# 2014-09-18    456.859985    456.859985    413.104004    424.440002
# 2014-09-19    424.102997    427.834991    384.532013    394.795990
# 2014-09-20    394.673004    423.295990    389.882996    408.903992
# 2014-09-21    408.084991    412.425995    393.181000    398.821014
# ...                  ...           ...           ...           ...
# 2023-05-20  26888.841797  27155.158203  26843.277344  27129.585938
# 2023-05-21  27118.423828  27265.917969  26706.921875  26753.826172
# 2023-05-22  26749.892578  27045.734375  26549.734375  26851.277344
# 2023-05-23  26855.960938  27434.683594  26816.179688  27225.726562
# 2023-05-24  27224.603516  27224.603516  26106.576172  26334.818359
#
#                  volume  edit_count  sentiment  neg_sentiment
# 2014-09-17     21056800         0.0        0.0            0.0
# 2014-09-18     34483200         0.0        0.0            0.0
# 2014-09-19     37919700         0.0        0.0            0.0
# 2014-09-20     36863600         0.0        0.0            0.0
# 2014-09-21     26580100         0.0        0.0            0.0
# ...                 ...         ...        ...            ...
# 2023-05-20   7044911360         0.0        0.0            0.0
# 2023-05-21   8647416921         0.0        0.0            0.0
# 2023-05-22  11056770492         0.0        0.0            0.0
# 2023-05-23  13697203143         0.0        0.0            0.0
# 2023-05-24  16299104428         0.0        0.0            0.0
#
# [3172 rows x 8 columns]

# %%
#close price of the day after
btc["tomorrow"] = btc["close"].shift(-1)

# %%
btc
# Out:
#                     open          high           low         close
# 2014-09-17    465.864014    468.174011    452.421997    457.334015  \
# 2014-09-18    456.859985    456.859985    413.104004    424.440002
# 2014-09-19    424.102997    427.834991    384.532013    394.795990
# 2014-09-20    394.673004    423.295990    389.882996    408.903992
# 2014-09-21    408.084991    412.425995    393.181000    398.821014
# ...                  ...           ...           ...           ...
# 2023-05-20  26888.841797  27155.158203  26843.277344  27129.585938
# 2023-05-21  27118.423828  27265.917969  26706.921875  26753.826172
# 2023-05-22  26749.892578  27045.734375  26549.734375  26851.277344
# 2023-05-23  26855.960938  27434.683594  26816.179688  27225.726562
# 2023-05-24  27224.603516  27224.603516  26106.576172  26334.818359
#
#                  volume  edit_count  sentiment  neg_sentiment      tomorrow
# 2014-09-17     21056800         0.0        0.0            0.0    424.440002
# 2014-09-18     34483200         0.0        0.0            0.0    394.795990
# 2014-09-19     37919700         0.0        0.0            0.0    408.903992
# 2014-09-20     36863600         0.0        0.0            0.0    398.821014
# 2014-09-21     26580100         0.0        0.0            0.0    402.152008
# ...                 ...         ...        ...            ...           ...
# 2023-05-20   7044911360         0.0        0.0            0.0  26753.826172
# 2023-05-21   8647416921         0.0        0.0            0.0  26851.277344
# 2023-05-22  11056770492         0.0        0.0            0.0  27225.726562
# 2023-05-23  13697203143         0.0        0.0            0.0  26334.818359
# 2023-05-24  16299104428         0.0        0.0            0.0           NaN
#
# [3172 rows x 9 columns]

# %%
#check if tomorrow is higher than today - convert boolean into an int
btc["target"] = (btc["tomorrow"] > btc["close"]).astype(int)

# %%
#check if classification is working
btc["target"].value_counts()
# Out:
# target
# 1    1685
# 0    1487
# Name: count, dtype: int64

# %%
btc
# Out:
#                     open          high           low         close
# 2014-09-17    465.864014    468.174011    452.421997    457.334015  \
# 2014-09-18    456.859985    456.859985    413.104004    424.440002
# 2014-09-19    424.102997    427.834991    384.532013    394.795990
# 2014-09-20    394.673004    423.295990    389.882996    408.903992
# 2014-09-21    408.084991    412.425995    393.181000    398.821014
# ...                  ...           ...           ...           ...
# 2023-05-20  26888.841797  27155.158203  26843.277344  27129.585938
# 2023-05-21  27118.423828  27265.917969  26706.921875  26753.826172
# 2023-05-22  26749.892578  27045.734375  26549.734375  26851.277344
# 2023-05-23  26855.960938  27434.683594  26816.179688  27225.726562
# 2023-05-24  27224.603516  27224.603516  26106.576172  26334.818359
#
#                  volume  edit_count  sentiment  neg_sentiment      tomorrow
# 2014-09-17     21056800         0.0        0.0            0.0    424.440002  \
# 2014-09-18     34483200         0.0        0.0            0.0    394.795990
# 2014-09-19     37919700         0.0        0.0            0.0    408.903992
# 2014-09-20     36863600         0.0        0.0            0.0    398.821014
# 2014-09-21     26580100         0.0        0.0            0.0    402.152008
# ...                 ...         ...        ...            ...           ...
# 2023-05-20   7044911360         0.0        0.0            0.0  26753.826172
# 2023-05-21   8647416921         0.0        0.0            0.0  26851.277344
# 2023-05-22  11056770492         0.0        0.0            0.0  27225.726562
# 2023-05-23  13697203143         0.0        0.0            0.0  26334.818359
# 2023-05-24  16299104428         0.0        0.0            0.0           NaN
#
#             target
# 2014-09-17       0
# 2014-09-18       0
# 2014-09-19       1
# 2014-09-20       0
# 2014-09-21       1
# ...            ...
# 2023-05-20       0
# 2023-05-21       1
# 2023-05-22       1
# 2023-05-23       0
# 2023-05-24       0
#
# [3172 rows x 10 columns]

# %%
#using random classifier to train algorithm withh the expected target
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(n_estimators=100, min_samples_split=50, random_state=1)

train = btc.iloc[:-200]
test = btc.iloc[-200:]

predictors = ["close", "volume", "open", "high", "low", "edit_count", "sentiment", "neg_sentiment"]
model.fit(train[predictors], train["target"])
# Out:
# RandomForestClassifier(min_samples_split=50, random_state=1)

# %%
#to test how accurate the prediction is - based on target made from previous data
from sklearn.metrics import precision_score

preds = model.predict(test[predictors])
preds = pd.Series(preds, index=test.index)
precision_score(test["target"], preds)
# Out:
# 0.504

# %%
#creates a function that combines the target and the predicted into one dataframe
def predict(train, test, predictors, model):
    model.fit(train[predictors], train["target"])
    preds = model.predict(test[predictors])
    preds = pd.Series(preds, index=test.index, name="predictions")
    combined = pd.concat([test["target"], preds], axis=1)
    return combined

# %%
#backtests data on over 3 years of data using dataframe created above
def backtest(data, model, predictors, start=1095, step=150):
    all_predictions = []

    for i in range(start, data.shape[0], step):
        train = data.iloc[0:i].copy()
        test = data.iloc[i:(i+step)].copy()
        predictions = predict(train, test, predictors, model)
        all_predictions.append(predictions)
    
    return pd.concat(all_predictions)

# %%
#different ML framework using backtesting and a different form of decision trees to create new predictions
from xgboost import XGBClassifier

model = XGBClassifier(random_state=1, learning_rate=.1, n_estimators=200)
predictions = backtest(btc, model, predictors)

# %%
#making sure the 1-0 classification for target data is working
predictions["predictions"].value_counts()
# Out:
# predictions
# 1    1360
# 0     717
# Name: count, dtype: int64

# %%
#compares actual values to predicted values
precision_score(predictions["target"], predictions["predictions"])
# Out:
# 0.5125

# %%
predictions
# Out:
#             target  predictions
# 2017-09-16       0            1
# 2017-09-17       1            0
# 2017-09-18       0            0
# 2017-09-19       0            1
# 2017-09-20       0            1
# ...            ...          ...
# 2023-05-20       0            1
# 2023-05-21       1            1
# 2023-05-22       1            1
# 2023-05-23       0            1
# 2023-05-24       0            1
#
# [2077 rows x 2 columns]

# %%
#finds trends through various columns in the last period of time
def compute_rolling(btc):
    horizons = [2,7,60,365] #each new predictor is checked every 1,7,60 and 365 days
    new_predictors = ["close", "sentiment", "neg_sentiment"]

    #computes rolling averages as new predictors
    for horizon in horizons:
        rolling_averages = btc.rolling(horizon, min_periods=1).mean()

        ratio_column = f"close_ratio_{horizon}"
        btc[ratio_column] = btc["close"] / rolling_averages["close"]
        
        edit_column = f"edit_{horizon}"
        btc[edit_column] = rolling_averages["edit_count"]

        rolling = btc.rolling(horizon, closed='left', min_periods=1).mean() #prevents data leakeage - not using present target to crate rolling average
        trend_column = f"trend_{horizon}"
        btc[trend_column] = rolling["target"]

        new_predictors+= [ratio_column, trend_column, edit_column]
    return btc, new_predictors

# %%
#computed rolling average over btc dataframe and puts value in new predictors
btc, new_predictors = compute_rolling(btc.copy())

# %%
#tests model with new parameters set above
predictions = backtest(btc, model, new_predictors)

# %%
#compare predictions again with target
precision_score(predictions["target"], predictions["predictions"])
# Out:
# 0.5091083413231065

# %%
predictions
# Out:
#             target  predictions
# 2017-09-16       0            1
# 2017-09-17       1            0
# 2017-09-18       0            0
# 2017-09-19       0            1
# 2017-09-20       0            1
# ...            ...          ...
# 2023-05-20       0            1
# 2023-05-21       1            1
# 2023-05-22       1            1
# 2023-05-23       0            1
# 2023-05-24       0            1
#
# [2077 rows x 2 columns]
